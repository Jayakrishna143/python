# %%
x = [12,13,34,35]
x.append(200)
print(x)
# Out:
# [12, 13, 34, 35, 200]

# %%
a = [1,2,[3,4],5,6]
b =a.copy()
print(a,b,sep='\t')
# Out:
# [1, 2, [3, 4], 5, 6]	[1, 2, [3, 4], 5, 6]

# %%
print(hex(id(a)),hex(id(b)),sep='\t')
print(hex(id(a[2])),hex(id(b[2])),sep='\t')
# Out:
# 0x7d8ec6a8ab40	0x7d8ead868680
# 0x7d8ec6a89e00	0x7d8ec6a89e00

# %%
a.extend('ab')
print(a,b,sep='\t')
# Out:
# [1, 2, [3, 4], 5, 6, 'a', 'b']	[1, 2, [3, 4], 5, 6]

# %%
a[2].append(555)
print(a,b,sep='\t')
# Out:
# [1, 2, [3, 4, 555, 555], 5, 6, 'a', 'b']	[1, 2, [3, 4, 555, 555], 5, 6]

# %%
# deep copy
import copy
from copy import deepcopy

b
# Out:
# [1, 2, [3, 4, 555, 555], 5, 6]

# %%
c = deepcopy(b)

# %%
print(hex(id(b)),hex(id(c)),sep='\t')
print(hex(id(b[2])),hex(id(c[2])),sep='\t')
# Out:
# 0x7d8ead868680	0x7d8ec6a89100
# 0x7d8ec6a89e00	0x7d8ec6a88b80

# %%
print(a,b,c,sep ='\n')
# Out:
# [1, 2, [3, 4, 555, 555], 5, 6, 'a', 'b']
# [1, 2, [3, 4, 555, 555], 5, 6]
# [1, 2, [3, 4, 555, 555], 5, 6]

# %%
id(a[-1])
# Out:
# 138053074818160

# %% [markdown]
# *   sets are unordered dynamic mutable clusters
# *  we enclose the values inside {} seperated by , or use set() class to perform typecasting
#
# *   sets don't entertain duplicates
# *   sets doesn't allow unhasable datatypes(which are mutable in nature)
#
#
# *   set() will create an enpty set

# %%
#sets
set()
a,b ={1,2,101,-5},set(['a','A',101])
print(a,b,sep='\t')
# sets are unordered
# Out:
# {1, 2, -5, 101}	{101, 'a', 'A'}

# %%
# sets don't entertain duplicates
c = {1,5,1,5}
d = {1,0,True,False,1.0,0.0}
c,d
# Out:
# ({1, 5}, {0, 1})

# %%
# creating
e = set()
print(e,type(e),len(e))
# Out:
# set() <class 'set'> 0
