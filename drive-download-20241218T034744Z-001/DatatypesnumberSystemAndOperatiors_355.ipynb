# %%
x= 509
y= 509

# %%
id(x), id(y)
# Out:
# (133052276230640, 133052276230800)

# %% [markdown]
# Variables conatins
#
# *   data type
# *   container
# *    immutable
# *
# *   List item

# %% [markdown]
# Rules
# 1.   keywords and predefined functions should not be used while naming a variable
# 2.   should not start with numbers and only starts with alphabet or underscore
#
# 3.   apart from underscore not supposed to used any other characters in naming the variables

# %%
import keyword
from keyword import kwlist

# %%
kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(kwlist)
# Out:
# 35

# %%
#packing
c= 555, 999
print (c, type(c))
# Out:
# (555, 999) <class 'tuple'>

# %%
#unpacking
a,b = (1010,5050)
print(a,b,sep ='\n')
# Out:
# 1010
# 5050

# %%
a,b = 1010,5050
print(a,b , type(a), type(b))
# Out:
# 1010 5050 <class 'int'> <class 'int'>

# %%
m = n = 808080
id (m), id(n)
# Out:
# (133051390789008, 133051390789008)

# %%
x =808080
y =8008080
id(x), id(y)
# Out:
# (133051390797200, 133051390788816)

# %% [markdown]
# # Arthamatic operators

# %%
x = 45
y= 16

z = x+y
z1 = x-y
z2 = x*y
z3 = x/y
z4 = x//y
z5 = x%y
z6 = x**y
print(z,z1,z2,z3,z4,z5,z6, sep = '\n')
# Out:
# 61
# 29
# 720
# 2.8125
# 2
# 13
# 282748441902441558837890625

# %% [markdown]
#  f string  is used in print function.for prittifing the result . {} are used so that the value of the element is displayed. it is used as a pointing of value

# %%
a = 10
b = 20
print(f'a has a value of {a} and b has a value {b}')
print(f'a+b is {a+b}')
print(f'a-b is {a-b}')
print(f'a*b is {a*b}')
print(f'a/b is {a/b}')
print(f'a//b is {a//b}')
print(f'a%b is {a%b}')
print(f'a**b is {a**b}')
# Out:
# a has a value of 10 and b has a value 20
# a+b is 30
# a-b is -10
# a*b is 200
# a/b is 0.5
# a//b is 0
# a%b is 10
# a**b is 100000000000000000000

# %%
# comparision operators {>,<,>=,<=,==,!=}
if a>b:
  print(f'{a} is greater than {b}')
elif a<b:
  print(f'{a} is less than {b}')
else:
  print(f'{b} is equal to  {a}')
# Out:
# 22 is less than 43

# %%
if a!=b:
  print(f'{a} is not equal to {b}')
else:
  print(f'{a} is equal to {b}')
# Out:
# 22 is not equal to 43

# %%
if a==b:
  print(f'{a} is equal to {b}')
else:
  print(f'{a} is not equal to {b}')
# Out:
# 45 is not equal to 36

# %%
bool(50)
# Out:
# True

# %%
a = input('enter a value:')
b = input('enter b value:')
# Out:
# enter a value45
# enter b value36

# %%
D = int(input('enter the Diameter of the circle:'))
R = D/2
print(f'Radius of the circle is {R}')
Area = 3.14*R**2
print(f'Area of the circle is {Area}')
circumferance = 2*3.14*R
print(f'circumferance of the circle is {circumferance} ')
# Out:
# enter the Diameter of the circle:13
# Radius of the circle is 6.5
# Area of the circle is 132.665
# circumferance of the circle is 40.82

# %%
if Area > 100:
   print("Area is grater than 100")
elif Area < 100:
   print("Area is less than 100")
else:
   print("Area is equal to 100")
# Out:
# Area is grater than 100

# %%
if   100 <= Area <= 150 :
   print("Area is grater than 100 and less than or equal to  150")
elif Area <= 100:
   print("Area is lesser than 100")
else:
   print("Area is above 150")
# Out:
# Area is grater than 100 but less than 150

# %%
number = int(input("Enter any number: "))
if number%2 == 1:
  if number%3 == 0:
    print(f'{number} is odd and divisible by 3')
  else:
    print(f'{number} is odd and not divisible by 3')
else:
  print(f'{number} is even')
# Out:
# Enter any number: 13
# 13 is odd and not divisible by 3

# %%
number = int(input("Enter any number: "))
if number%2 != 0 and number%3 == 0:
  print(f'{number} is odd and a multiple of 3')
elif number%2 == 0 and number%3 == 0:
  print(f'{number} is even and a multiple of 3')
elif number%2 ==0 and number%3 != 0:
  print(f'{number} is even and not a multiple of 3')
else:
  print(f'{number } is odd and not a multiple of 3')
# Out:
# Enter any number: 17
# 17 is odd and not a multiple of 3

# %%
# membership operators
# in and not in,, This operators only work in lists,tulips,dic,sets

'a ' in 'Hello', 'h' in 'hello', 'a' in['a','b']
# Out:
# (False, True, True)

# %%
word = input('enter a word:')
if 'm' in word and 'M' in word:
  print(f' m and M  are  present in {word}')
elif 'm' in word:
  print(f'm is  present in {word}')
elif 'M' in word:
  print(f'M is  present in {word}')
else:
  print(f'm and M are not present in {word}')
# Out:
# enter a word:Man
# M is  present in Man

# %%
ord('A')
# Out:
# 65

# %%
chr(Char)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-448298dc69db> in <cell line: 1>()
# ----> 1 chr(Char)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
x = input('enter a character:')
assert (65<= ord(x) <=90)  or (97<= ord(x)<=122),'please enter a english alphabet'
if ord(x)>=65 and ord(x)<=90:
  print(f'The capital of{x } is {chr(ord(x)+32)}')
elif ord(x)>=97 and ord(x)<=122:
  print(f'The capital of{x} is {chr(ord(x)-32)}')
# Out:
# enter a word:man
# enter a character:m
# The capital ofm is M

# %%
a = input('enter a character:') #input
assert (65<= ord(a) <=90)  or (97<= ord(a)<=122),'please enter a english alphabet' #checking weather given char is an English alphabet if not code ends here with "please enter an english alphabet"
if 65<= ord(a) <=90: #check weather the ord(a) ie the given charater is Captial if capital adds 32 so that it is convered to smaller
  b = chr(ord(a)+32)
else:
  b = chr(ord(a)-32) #check weather the ord(a) ie the given charater is small if capital sub 32 so that it is convered to capital
y = a,b

x = input('enter a string: ') #input string
if y[0] in x and y[1] in x: #characters are present in both capital and smaller for then its true
  print(f'{y[0]} and {y[1]} are present in {x}')
elif  y[0] in x: #if capital is present this prints output
  print(f'{y[0]} is present in {x}')
elif y[1] in x:# if small letter is present this prints output
  print(f'{y[1]} is present in {x}')
else :
  print(f'{y[0]} and {y[1]} are not present in {x}')
# Out:
# enter a character:A
# enter a string: animal
# a is present in animal

# %%
#identity operator
#questioning if the values have the same memory address or not
a = 505
b = 505
a == b
# Out:
# True

# %%
id(a), id(b)
# Out:
# (133580286429520, 133580286442928)
